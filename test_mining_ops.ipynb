# %% [markdown]
# # <font color=#c51b8a>Mine-n-Match (MnM) Mini Tutorial:</font>
# ### Make sure to load all the neccessary imports everytime you open this notebook!

# %%
# Import functions for mining NCBI
from mine_ncbi_functions import ncbi_fetch_species, ncbi_mine_seq_data 
# Import json so we can load any existing 
import json
# Email for when we query NCBI
email = "sethfrazer@ucsb.edu"  # Replace with your email

# %% [markdown]
# ## <font color=#c994c7>Step 1: Create a Taxonomy Database</font>

# %%
# Example usage:
taxa = "Mammalia"
rank = "class"
limit = 500
report_dir = 'taxonomy_data'
out_file = "mammalia_taxonomy"

# If verbose = True then you will see alot of information printed when you run this function
# Also, if you hover your mouse over any of MY functions then you should get a pop-up with more information on how to use them
species_data = ncbi_fetch_species(email, report_dir=report_dir, out=out_file, taxa=taxa, rank=rank, limit=limit, verbose=True)

# Print the first few entries of the dictionary as an example:
count = 0
for species, lineage in species_data.items():
    print(f"{species}: {lineage}")
    count += 1
    if count >= 5:
        break
# Out:
# Searching for TaxID for Mammalia...
# Found TaxID: 40674
# Finding direct children of Mammalia...
# Found 28 direct children.
#   - Child Taxon: Litopterna (TaxID: 1563124)
#   - Child Taxon: Notoungulata (TaxID: 1563120)
#   - Child Taxon: Cingulata (TaxID: 948951)
#   - Child Taxon: Pilosa (TaxID: 948950)
#   - Child Taxon: Artiodactyla (TaxID: 91561)
#   - Child Taxon: Peramelemorphia (TaxID: 38611)
#   - Child Taxon: Notoryctemorphia (TaxID: 38610)
#   - Child Taxon: Diprotodontia (TaxID: 38609)
#   - Child Taxon: Dasyuromorphia (TaxID: 38608)
#   - Child Taxon: Microbiotheria (TaxID: 38607)
#   - Child Taxon: Paucituberculata (TaxID: 38606)
#   - Child Taxon: Didelphimorphia (TaxID: 38605)
#   - Child Taxon: Carnivora (TaxID: 33554)
#   - Child Taxon: Dermoptera (TaxID: 30656)
#   - Child Taxon: Macroscelidea (TaxID: 28734)
#   - Child Taxon: Rodentia (TaxID: 9989)
#   - Child Taxon: Lagomorpha (TaxID: 9975)
#   - Child Taxon: Pholidota (TaxID: 9971)
#   - Child Taxon: Tubulidentata (TaxID: 9815)
#   - Child Taxon: Hyracoidea (TaxID: 9810)
#   - Child Taxon: Perissodactyla (TaxID: 9787)
#   - Child Taxon: Proboscidea (TaxID: 9779)
#   - Child Taxon: Sirenia (TaxID: 9774)
#   - Child Taxon: Primates (TaxID: 9443)
#   - Child Taxon: Chiroptera (TaxID: 9397)
#   - Child Taxon: Scandentia (TaxID: 9392)
#   - Child Taxon: Eulipotyphla (TaxID: 9362)
#   - Child Taxon: Monotremata (TaxID: 9255)
#
# Fetching up to 18 species for child TaxID 1563124...
# [{'TaxId': '1970152', 'ScientificName': 'Macrauchenia sp. MW-2017', 'ParentTaxId': '2618932', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Litopterna; Macraucheniidae; Macrauchenia; unclassified Macrauchenia', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '32525', 'ScientificName': 'Theria', 'Rank': 'clade'}, {'TaxId': '9347', 'ScientificName': 'Eutheria', 'Rank': 'clade'}, {'TaxId': '1563124', 'ScientificName': 'Litopterna', 'Rank': 'order'}, {'TaxId': '1563125', 'ScientificName': 'Macraucheniidae', 'Rank': 'family'}, {'TaxId': '1563126', 'ScientificName': 'Macrauchenia', 'Rank': 'genus'}, {'TaxId': '2618932', 'ScientificName': 'unclassified Macrauchenia', 'Rank': 'no rank'}], 'CreateDate': '2017/03/20 17:19:06', 'UpdateDate': '2017/07/08 01:18:58', 'PubDate': '2017/07/08 01:00:50'}, {'TaxId': '1566623', 'ScientificName': 'Macrauchenia patachonica', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Macrauchenia patachonica Owen, 1838'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': [], 'Acronym': [], 'CommonName': []}, 'ParentTaxId': '1563126', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Litopterna; Macraucheniidae; Macrauchenia', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'Scientific ...
#   Processing: Macrauchenia sp. MW-2017
#   Processing: Macrauchenia patachonica
#   Processing: Macrauchenia sp. FW-2014
# Fetched and processed 3 species.
#
# Fetching up to 18 species for child TaxID 1563120...
# [{'TaxId': '1563122', 'ScientificName': 'Toxodon sp. FW-2014', 'ParentTaxId': '2630100', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Notoungulata; Toxodontidae; Toxodon; unclassified Toxodon', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '32525', 'ScientificName': 'Theria', 'Rank': 'clade'}, {'TaxId': '9347', 'ScientificName': 'Eutheria', 'Rank': 'clade'}, {'TaxId': '1563120', 'ScientificName': 'Notoungulata', 'Rank': 'order'}, {'TaxId': '1563123', 'ScientificName': 'Toxodontidae', 'Rank': 'family'}, {'TaxId': '1563121', 'ScientificName': 'Toxodon', 'Rank': 'genus'}, {'TaxId': '2630100', 'ScientificName': 'unclassified Toxodon', 'Rank': 'no rank'}], 'CreateDate': '2014/10/22 10:49:11', 'UpdateDate': '2015/08/04 13:17:22', 'PubDate': '2015/08/04 13:00:50'}]
#   Processing: Toxodon sp. FW-2014
# Fetched and processed 1 species.
#
# Fetching up to 18 species for child TaxID 948951...
# [{'TaxId': '1756214', 'ScientificName': 'Cabassous tatouay', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Cabassous tatouay (Desmarest, 1804)'}, {'ClassCDE': 'authority', 'DispName': 'Dasypus tatouay Desmarest, 1804'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': ['Dasypus tatouay'], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': 'greater naked-tailed armadillo'}, 'ParentTaxId': '48851', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Xenarthra; Cingulata; Chlamyphoridae; Cabassous', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '32525', 'ScientificName': 'Theria', 'Rank': 'clade'}, {'TaxId': '9347', 'ScientificName': 'Eutheria', 'Rank': 'clade'}, {'TaxId': '9348', 'ScientificName': 'Xenarthra', 'Rank': 'superorder'}, {'TaxId': '948951', 'ScientificName': 'Cingulata', 'Rank': 'order'}, {'TaxId': '1811493', 'ScientificName': 'Chlamyphoridae', 'Rank': 'family'}, {'TaxId': '48851', 'ScientificName': 'Cabassous', 'Rank': 'genus'}], 'CreateDate': '2015/11/16 15:47:27', 'UpdateDate': '2017/06/14 10:56:24', 'PubDate': '2015/11/25 01:02:24'}, {'TaxId': '183750', 'ScientificName': 'Tolypeutes tricinctus', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Dasypus tricinctus Linnæus, 1758'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': ['Dasypus tricinctus'], 'Acronym': [], 'CommonName': []}, 'ParentTaxId': '183748', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Xenarthra; Cingulata; Chlamyphoridae; Tolypeutes', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33 ...
#   Processing: Cabassous tatouay
#   Processing: Tolypeutes tricinctus
#   Processing: Dasypus novemcinctus
#   Processing: Euphractus sexcinctus
#   Processing: Cabassous centralis
#   Processing: Neuryurus rudis
#   Processing: Cabassous chacoensis
#   Processing: Doedicurus sp.
#   Processing: Dasypus bellus
#   Processing: Dasypus sp.
#   Processing: Chlamyphorus truncatus
#   Processing: Chaetophractus vellerosus
#   Processing: Dasypus septemcinctus
#   Processing: Dasypus hybridus
#   Processing: Cingulata sp. BOLD:AAE3389
#   Processing: Neuryurus sp. MPM2019
#   Processing: Dasypus sp. VJL-2004
#   Processing: Glyptodon sp. SLP-2019
# Fetched and processed 18 species.
#
# Fetching up to 18 species for child TaxID 948950...
# [{'TaxId': '2591764', 'ScientificName': 'Glossotherium robustum', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Glossotherium robustum Owen, 1842'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': ['Glossotherium sp. SLP-2019'], 'Synonym': [], 'Acronym': [], 'CommonName': []}, 'ParentTaxId': '2546653', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Xenarthra; Pilosa; Folivora; Mylodontidae; Glossotherium', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '32525', 'ScientificName': 'Theria', 'Rank': 'clade'}, {'TaxId': '9347', 'ScientificName': 'Eutheria', 'Rank': 'clade'}, {'TaxId': '9348', 'ScientificName': 'Xenarthra', 'Rank': 'superorder'}, {'TaxId': '948950', 'ScientificName': 'Pilosa', 'Rank': 'order'}, {'TaxId': '948953', 'ScientificName': 'Folivora', 'Rank': 'suborder'}, {'TaxId': '48781', 'ScientificName': 'Mylodontidae', 'Rank': 'family'}, {'TaxId': '2546653', 'ScientificName': 'Glossotherium', 'Rank': 'genus'}], 'CreateDate': '2019/06/27 09:38:26', 'UpdateDate': '2019/07/01 16:46:14', 'PubDate': '2019/11/20 01:03:23'}, {'TaxId': '927259', 'ScientificName': 'Choloepus didactylus x hoffmanni', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': ['Choloepus didactylus x Choloepus hoffmanni'], 'Acronym': [], 'CommonName': []}, 'ParentTaxId': '9357', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Xenarthra; Pilosa; Folivora; Megalonychidae; Choloepus', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '60 ...
#   Processing: Glossotherium robustum
#   Processing: Choloepus didactylus x hoffmanni
#   Processing: Acratocnus ye
#   Processing: Cyclopes rufus
#   Processing: Parocnus serus
#   Processing: Choloepus hoffmanni
#   Processing: Scelidodon sp. SLP-2019
#   Processing: Choloepus didactylus
#   Processing: Pilosa sp. BOLD:AAJ5166
#   Processing: Bradypus tridactylus
#   Processing: Bradypus sp. DEW-2006
#   Processing: Bradypus variegatus
#   Processing: Mylodon darwinii
#   Processing: Scelidotherium sp. SLP-2019
#   Processing: Megatherium americanum
#   Processing: Tamandua tetradactyla
#   Processing: Neocnus dousman
#   Processing: Neocnus comes
# Fetched and processed 18 species.
#
# Fetching up to 18 species for child TaxID 91561...
# [{'TaxId': '1954430', 'ScientificName': 'Muntiacus sp. JAV13', 'ParentTaxId': '2620652', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Boreoeutheria; Laurasiatheria; Artiodactyla; Ruminantia; Pecora; Cervidae; Muntiacinae; Muntiacus; unclassified Muntiacus', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '32525', 'ScientificName': 'Theria', 'Rank': 'clade'}, {'TaxId': '9347', 'ScientificName': 'Eutheria', 'Rank': 'clade'}, {'TaxId': '1437010', 'ScientificName': 'Boreoeutheria', 'Rank': 'clade'}, {'TaxId': '314145', 'ScientificName': 'Laurasiatheria', 'Rank': 'superorder'}, {'TaxId': '91561', 'ScientificName': 'Artiodactyla', 'Rank': 'order'}, {'TaxId': '9845', 'ScientificName': 'Ruminantia', 'Rank': 'suborder'}, {'TaxId': '35500', 'ScientificName': 'Pecora', 'Rank': 'infraorder'}, {'TaxId': '9850', 'ScientificName': 'Cervidae', 'Rank': 'family'}, {'TaxId': '34877', 'ScientificName': 'Muntiacinae', 'Rank': 'subfamily'}, {'TaxId': '9885', 'ScientificName': 'Muntiacus', 'Rank': 'genus'}, {'TaxId': '2620652', 'ScientificName': 'unclassified Muntiacus', 'Rank': 'no rank'}], 'CreateDate': '2017/02/07 17:11:15', 'UpdateDate': '2017/03/01 13:18:22', 'PubDate': '2017/03/01 13:00:50'}, {'TaxId': '1922215', 'ScientificName': 'Bootherium bombifrons', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Bison bombifrons Allen, 1874'}, {'ClassCDE': 'authority', 'DispName': 'Bootherium bombifrons (Harlan, 1825)'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': ['Bison bombifrons'], 'Acronym': [], 'CommonName': []}, 'ParentTaxId': '1922214', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Boreoeutheria; Laurasiatheria; Artiodactyla; Ruminantia; Pecora; Bovidae; Caprinae; Bootherium', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', ' ...
#   Processing: Muntiacus sp. JAV13
#   Processing: Bootherium bombifrons
#   Processing: Lama glama
#   Processing: Mazama sp. PERD011
#   Processing: Caperea marginata
#   Processing: Bison priscus
#   Processing: Muntiacus sp. SUM2
#   Processing: Redunca arundinum
#   Processing: Tasmacetus shepherdi
#   Processing: Ovis sp.
#   Processing: Rangifer tarandus
#   Processing: Rusa alfredi
#   Processing: Moschus sp. NYSZ-Bu75
#   Processing: Muntiacus sp. IND7
#   Processing: Bison antiquus
#   Processing: Neophocaena asiaeorientalis
#   Processing: Muntiacus sp. JAV7
#   Processing: Capra walie
# Fetched and processed 18 species.
#
# Fetching up to 18 species for child TaxID 38611...
# [{'TaxId': '65612', 'ScientificName': 'Isoodon obesulus', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Didelphis obesula Shaw, 1797'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': ['Didelphis obesula'], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': 'southern brown bandicoot'}, 'ParentTaxId': '37888', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Metatheria; Peramelemorphia; Peramelidae; Isoodon', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '32525', 'ScientificName': 'Theria', 'Rank': 'clade'}, {'TaxId': '9263', 'ScientificName': 'Metatheria', 'Rank': 'clade'}, {'TaxId': '38611', 'ScientificName': 'Peramelemorphia', 'Rank': 'order'}, {'TaxId': '9342', 'ScientificName': 'Peramelidae', 'Rank': 'family'}, {'TaxId': '37888', 'ScientificName': 'Isoodon', 'Rank': 'genus'}], 'CreateDate': '1997/09/11 13:35:00', 'UpdateDate': '2017/06/14 10:56:24', 'PubDate': '1998/01/06 00:00:00'}, {'TaxId': '92651', 'ScientificName': 'Macrotis lagotis', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Perameles lagotis Reid, 1837'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': ['Perameles lagotis'], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': 'bilby'}, 'ParentTaxId': '92650', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Metatheria; Peramelemorphia; Peramelidae; Macrotis', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName':  ...
#   Processing: Isoodon obesulus
#   Processing: Macrotis lagotis
#   Processing: Perameles eremiana
#   Processing: Macrotis leucura
#   Processing: Perameles nasuta
#   Processing: Perameles bougainville
#   Processing: Isoodon peninsulae
#   Processing: Microperoryctes murina
#   Processing: Microperoryctes papuensis
#   Processing: Peroryctes broadbenti
#   Processing: Echymipera rufescens
#   Processing: Microperoryctes sp. RWM-2011
#   Processing: Rhynchomeles prattorum
#   Processing: Isoodon fusciventer
#   Processing: Isoodon auratus
#   Processing: Perameles gunnii
#   Processing: Echymipera kalubu
#   Processing: Peroryctes raffrayana
# Fetched and processed 18 species.
#
# Fetching up to 18 species for child TaxID 38610...
# [{'TaxId': '203824', 'ScientificName': 'Notoryctes caurinus', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Notoryctes caurinus Thomas, 1920'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': [], 'Acronym': [], 'CommonName': []}, 'ParentTaxId': '37887', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Metatheria; Notoryctemorphia; Notoryctidae; Notoryctes', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '32525', 'ScientificName': 'Theria', 'Rank': 'clade'}, {'TaxId': '9263', 'ScientificName': 'Metatheria', 'Rank': 'clade'}, {'TaxId': '38610', 'ScientificName': 'Notoryctemorphia', 'Rank': 'order'}, {'TaxId': '30662', 'ScientificName': 'Notoryctidae', 'Rank': 'family'}, {'TaxId': '37887', 'ScientificName': 'Notoryctes', 'Rank': 'genus'}], 'CreateDate': '2002/05/08 12:00:00', 'UpdateDate': '2020/04/28 22:18:58', 'PubDate': '2003/06/05 18:03:00'}, {'TaxId': '37699', 'ScientificName': 'Notoryctes typhlops', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Psammoryctes typhlops Stirling, 1889'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': ['Psammoryctes typhlops'], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': 'marsupial mole'}, 'ParentTaxId': '37887', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Metatheria; Notoryctemorphia; Notoryctidae; Notoryctes', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank':  ...
#   Processing: Notoryctes caurinus
#   Processing: Notoryctes typhlops
# Fetched and processed 2 species.
#
# Fetching up to 18 species for child TaxID 38609...
# [{'TaxId': '413582', 'ScientificName': 'Notamacropus parma', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Macropus parma Waterhouse, 1845'}, {'ClassCDE': 'authority', 'DispName': 'Notamacropus parma (Waterhouse, 1846)'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': ['Macropus parma'], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': 'Parma wallaby'}, 'ParentTaxId': '1960649', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Metatheria; Diprotodontia; Macropodidae; Notamacropus', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '32525', 'ScientificName': 'Theria', 'Rank': 'clade'}, {'TaxId': '9263', 'ScientificName': 'Metatheria', 'Rank': 'clade'}, {'TaxId': '38609', 'ScientificName': 'Diprotodontia', 'Rank': 'order'}, {'TaxId': '9307', 'ScientificName': 'Macropodidae', 'Rank': 'family'}, {'TaxId': '1960649', 'ScientificName': 'Notamacropus', 'Rank': 'genus'}], 'CreateDate': '2006/11/24 10:21:18', 'UpdateDate': '2018/10/29 19:32:20', 'PubDate': '2008/02/23 18:00:17'}, {'TaxId': '710129', 'ScientificName': 'Thylogale browni', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Halmaturus browni Ramsay, 1877'}, {'ClassCDE': 'authority', 'DispName': 'Thylogale browni (Ramsay, 1887)'}, {'ClassCDE': 'authority', 'DispName': 'Thylogale brownii (Ramsay, 1877)'}, {'ClassCDE': 'misspelling', 'DispName': 'Thylogale brownii'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': ['Halmaturus browni'], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': "Brown's pademelon"}, 'ParentTaxId': '9326', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Metatheria; Diprotodontia; Macropodidae; Thylogale', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId' ...
#   Processing: Notamacropus parma
#   Processing: Thylogale browni
#   Processing: Petaurus sp. MO01
#   Processing: Dorcopsis hageni
#   Processing: Phalanger sp. Gorom island
#   Processing: Spilocuscus maculatus
#   Processing: Trichosurus cunninghami
#   Processing: Pseudochirops albertisii
#   Processing: Thylogale stigmatica
#   Processing: Dendrolagus ursinus
#   Processing: Lasiorhinus krefftii
#   Processing: Trichosurus caninus
#   Processing: Phalanger sp. Wanggar Nabire island
#   Processing: Phalanger sp. AMS M16263
#   Processing: Hemibelideus lemuroides
#   Processing: Phalanger sp. Moor Nabire island
#   Processing: Macropus sp. MG003
#   Processing: Petaurus notatus
# Fetched and processed 18 species.
#
# Fetching up to 18 species for child TaxID 38608...
# [{'TaxId': '1985244', 'ScientificName': 'Planigale sp. PLANMW1189', 'ParentTaxId': '2626615', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Metatheria; Dasyuromorphia; Dasyuridae; Planigale; unclassified Planigale', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '32525', 'ScientificName': 'Theria', 'Rank': 'clade'}, {'TaxId': '9263', 'ScientificName': 'Metatheria', 'Rank': 'clade'}, {'TaxId': '38608', 'ScientificName': 'Dasyuromorphia', 'Rank': 'order'}, {'TaxId': '9277', 'ScientificName': 'Dasyuridae', 'Rank': 'family'}, {'TaxId': '9296', 'ScientificName': 'Planigale', 'Rank': 'genus'}, {'TaxId': '2626615', 'ScientificName': 'unclassified Planigale', 'Rank': 'no rank'}], 'CreateDate': '2017/05/03 16:17:32', 'UpdateDate': '2017/05/24 13:19:00', 'PubDate': '2017/05/24 13:00:49'}, {'TaxId': '75753', 'ScientificName': 'Sminthopsis aitkeni', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Sminthopsis aitkeni Kitchener, Stoddart & Henry, 1984'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': [], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': 'Kangaroo Island dunnart'}, 'ParentTaxId': '9300', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Metatheria; Dasyuromorphia; Dasyuridae; Sminthopsis', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subp ...
#   Processing: Planigale sp. PLANMW1189
#   Processing: Sminthopsis aitkeni
#   Processing: Dasyurus viverrinus
#   Processing: Antechinus stuartii
#   Processing: Antechinus adustus
#   Processing: Myoictis wavicus
#   Processing: Antechinus argentus
#   Processing: Phascogale pirata
#   Processing: Planigale tenuirostris
#   Processing: Sminthopsis sp. HHAM-2003
#   Processing: Sminthopsis murina
#   Processing: Ningaui sp. PLANIMW851
#   Processing: Dasyurus albopunctatus
#   Processing: Dasycercus blythi
#   Processing: Myoictis leucura
#   Processing: Sminthopsis hirtipes
#   Processing: Sminthopsis virginiae
#   Processing: Sminthopsis psammophila
# Fetched and processed 18 species.
#
# Fetching up to 18 species for child TaxID 38607...
# [{'TaxId': '2080854', 'ScientificName': 'Dromiciops bozinovici', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': "Dromiciops bozinovici D'Elia, Hurtado & D'Anatro, 2016"}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': [], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': 'Panchoss monito del monte'}, 'ParentTaxId': '33561', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Metatheria; Microbiotheria; Microbiotheriidae; Dromiciops', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '32525', 'ScientificName': 'Theria', 'Rank': 'clade'}, {'TaxId': '9263', 'ScientificName': 'Metatheria', 'Rank': 'clade'}, {'TaxId': '38607', 'ScientificName': 'Microbiotheria', 'Rank': 'order'}, {'TaxId': '30660', 'ScientificName': 'Microbiotheriidae', 'Rank': 'family'}, {'TaxId': '33561', 'ScientificName': 'Dromiciops', 'Rank': 'genus'}], 'CreateDate': '2018/02/01 14:56:15', 'UpdateDate': '2018/07/13 14:46:14', 'PubDate': '2021/07/02 01:03:25'}, {'TaxId': '33562', 'ScientificName': 'Dromiciops gliroides', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Dromiciops gliroides Thomas, 1894'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': ['Dromiciops australis'], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': 'monito del monte'}, 'ParentTaxId': '33561', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Metatheria; Microbiotheria; Microbiotheriidae; Dromiciops', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumet ...
#   Processing: Dromiciops bozinovici
#   Processing: Dromiciops gliroides
# Fetched and processed 2 species.
#
# Fetching up to 18 species for child TaxID 38606...
# ...
#   Processing: Phyllonycteris poeyi
#   Processing: Miniopterus cf. arenarius VG-2013
#   Processing: Macrotus californicus
#   Processing: Molossus sp. Santa Fe190
#   Processing: Rhinolophus landeri
#   Processing: Myotis sp. 1145/20_SP
#   Processing: Nyctimene vizcaccia
#   Processing: Chiroptera sp. B1398
#   Processing: Chiroptera sp. BOLD:AAM4700
#   Processing: Natalus tumidirostris
#   Processing: Myotis cf. davidii ZMB Mam 108356
#   Processing: Hipposideros sp. 1 LEP-2013
#   Processing: Mormoops megalophylla
#   Processing: Neoeptesicus innoxius
#   Processing: Myotis armiensis
#   Processing: Anoura cadenai
#   Processing: Myotis frater
# Fetched and processed 17 species.
#
# Fetching up to 17 species for child TaxID 9392...
# [{'TaxId': '320358', 'ScientificName': 'Tupaia nicobarica', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': [], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': 'Nicobar tree shrew'}, 'ParentTaxId': '9394', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Boreoeutheria; Euarchontoglires; Scandentia; Tupaiidae; Tupaia', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '32525', 'ScientificName': 'Theria', 'Rank': 'clade'}, {'TaxId': '9347', 'ScientificName': 'Eutheria', 'Rank': 'clade'}, {'TaxId': '1437010', 'ScientificName': 'Boreoeutheria', 'Rank': 'clade'}, {'TaxId': '314146', 'ScientificName': 'Euarchontoglires', 'Rank': 'superorder'}, {'TaxId': '9392', 'ScientificName': 'Scandentia', 'Rank': 'order'}, {'TaxId': '9393', 'ScientificName': 'Tupaiidae', 'Rank': 'family'}, {'TaxId': '9394', 'ScientificName': 'Tupaia', 'Rank': 'genus'}], 'CreateDate': '2005/03/23 12:18:14', 'UpdateDate': '2017/06/14 10:56:24', 'PubDate': '2005/05/07 18:01:19'}, {'TaxId': '320341', 'ScientificName': 'Tupaia dorsalis', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Tupaia dorsalis Schlegel, 1857'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': [], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': 'striped tree shrew'}, 'ParentTaxId': '9394', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Boreoeutheria; Euarchontoglires; Scandentia; Tupaiidae; Tupaia', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '607 ...
#   Processing: Tupaia nicobarica
#   Processing: Tupaia dorsalis
#   Processing: Urogale everetti
#   Processing: Dendrogale melanura
#   Processing: Tupaia montana
#   Processing: Tupaia sp. P. Deininger
#   Processing: Tupaia gracilis
#   Processing: Tupaia tana
#   Processing: Dendrogale murina
#   Processing: Tupaia belangeri
#   Processing: Tupaia chinensis
#   Processing: Tupaia glis
#   Processing: Tupaia moellendorffi
#   Processing: Tupaia chrysogaster
#   Processing: Tupaia minor
#   Processing: Tupaia splendidula
#   Processing: Anathana ellioti
# Fetched and processed 17 species.
#
# Fetching up to 17 species for child TaxID 9362...
# [{'TaxId': '214447', 'ScientificName': 'Crocidura maurisca', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Crocidura maurisca Thomas, 1904'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': [], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': 'dark shrew'}, 'ParentTaxId': '36801', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Boreoeutheria; Laurasiatheria; Eulipotyphla; Soricidae; Crocidurinae; Crocidura', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '32525', 'ScientificName': 'Theria', 'Rank': 'clade'}, {'TaxId': '9347', 'ScientificName': 'Eutheria', 'Rank': 'clade'}, {'TaxId': '1437010', 'ScientificName': 'Boreoeutheria', 'Rank': 'clade'}, {'TaxId': '314145', 'ScientificName': 'Laurasiatheria', 'Rank': 'superorder'}, {'TaxId': '9362', 'ScientificName': 'Eulipotyphla', 'Rank': 'order'}, {'TaxId': '9376', 'ScientificName': 'Soricidae', 'Rank': 'family'}, {'TaxId': '183662', 'ScientificName': 'Crocidurinae', 'Rank': 'subfamily'}, {'TaxId': '36801', 'ScientificName': 'Crocidura', 'Rank': 'genus'}], 'CreateDate': '2002/05/08 12:00:00', 'UpdateDate': '2020/04/28 22:04:14', 'PubDate': '2004/11/01 18:01:33'}, {'TaxId': '2995527', 'ScientificName': 'Podogymnura aureospinula', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Podogymnura aureospinula Heaney & Morgan, 1982'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': [], 'Acronym': [], 'CommonName': []}, 'ParentTaxId': '48904', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Theria; Eutheria; Boreoeutheria; Laurasiatheria; Eulipotyphla; Erinaceidae; Galericinae; Podogymnura', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'su ...
#   Processing: Crocidura maurisca
#   Processing: Podogymnura aureospinula
#   Processing: Euroscaptor sp. 2 TE-2021
#   Processing: Insectivora sp. BOLD:AAE3121
#   Processing: Sylvisorex granti
#   Processing: Talpa ognevi
#   Processing: Crocidura sp. SSWM-2009a
#   Processing: Crocidura voi
#   Processing: Sorex alpinus
#   Processing: Crocidura sp. ETH6122
#   Processing: Sorex cansulus
#   Processing: Crocidura lea
#   Processing: Chimarrogale styani
#   Processing: Cryptotis obscurus
#   Processing: Crocidura sp. DPL-2017
#   Processing: Atelerix sp. isolate 6647 CF-2019
#   Processing: Uropsilus aequodonenia
# Fetched and processed 17 species.
#
# Fetching up to 17 species for child TaxID 9255...
# [{'TaxId': '1684342', 'ScientificName': 'Zaglossus bartoni', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Acanthoglossus bruijnii bartoni Thomas, 1907'}, {'ClassCDE': 'authority', 'DispName': 'Zaglossus bartoni (Thomas, 1907)'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': ['Acanthoglossus bruijnii bartoni'], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': 'Eastern long-beaked echidna'}, 'ParentTaxId': '33542', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Prototheria; Monotremata; Tachyglossidae; Zaglossus', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': 'Eumetazoa', 'Rank': 'clade'}, {'TaxId': '33213', 'ScientificName': 'Bilateria', 'Rank': 'clade'}, {'TaxId': '33511', 'ScientificName': 'Deuterostomia', 'Rank': 'clade'}, {'TaxId': '7711', 'ScientificName': 'Chordata', 'Rank': 'phylum'}, {'TaxId': '89593', 'ScientificName': 'Craniata', 'Rank': 'subphylum'}, {'TaxId': '7742', 'ScientificName': 'Vertebrata', 'Rank': 'clade'}, {'TaxId': '7776', 'ScientificName': 'Gnathostomata', 'Rank': 'clade'}, {'TaxId': '117570', 'ScientificName': 'Teleostomi', 'Rank': 'clade'}, {'TaxId': '117571', 'ScientificName': 'Euteleostomi', 'Rank': 'clade'}, {'TaxId': '8287', 'ScientificName': 'Sarcopterygii', 'Rank': 'superclass'}, {'TaxId': '1338369', 'ScientificName': 'Dipnotetrapodomorpha', 'Rank': 'clade'}, {'TaxId': '32523', 'ScientificName': 'Tetrapoda', 'Rank': 'clade'}, {'TaxId': '32524', 'ScientificName': 'Amniota', 'Rank': 'clade'}, {'TaxId': '40674', 'ScientificName': 'Mammalia', 'Rank': 'class'}, {'TaxId': '9254', 'ScientificName': 'Prototheria', 'Rank': 'clade'}, {'TaxId': '9255', 'ScientificName': 'Monotremata', 'Rank': 'order'}, {'TaxId': '9259', 'ScientificName': 'Tachyglossidae', 'Rank': 'family'}, {'TaxId': '33542', 'ScientificName': 'Zaglossus', 'Rank': 'genus'}], 'CreateDate': '2015/07/15 16:51:13', 'UpdateDate': '2017/06/14 10:56:24', 'PubDate': '2016/07/14 13:00:49'}, {'TaxId': '1684341', 'ScientificName': 'Zaglossus attenboroughi', 'OtherNames': {'Misspelling': [], 'Inpart': [], 'Misnomer': [], 'Teleomorph': [], 'EquivalentName': [], 'Name': [{'ClassCDE': 'authority', 'DispName': 'Zaglossus attenboroughi Flannery & Groves, 1998'}], 'Anamorph': [], 'GenbankSynonym': [], 'GenbankAnamorph': [], 'Includes': [], 'Synonym': [], 'Acronym': [], 'CommonName': [], 'GenbankCommonName': "Sir David's long-beaked echidna"}, 'ParentTaxId': '33542', 'Rank': 'species', 'Division': 'Mammals', 'GeneticCode': {'GCId': '1', 'GCName': 'Standard'}, 'MitoGeneticCode': {'MGCId': '2', 'MGCName': 'Vertebrate Mitochondrial'}, 'Lineage': 'cellular organisms; Eukaryota; Opisthokonta; Metazoa; Eumetazoa; Bilateria; Deuterostomia; Chordata; Craniata; Vertebrata; Gnathostomata; Teleostomi; Euteleostomi; Sarcopterygii; Dipnotetrapodomorpha; Tetrapoda; Amniota; Mammalia; Prototheria; Monotremata; Tachyglossidae; Zaglossus', 'LineageEx': [{'TaxId': '131567', 'ScientificName': 'cellular organisms', 'Rank': 'no rank'}, {'TaxId': '2759', 'ScientificName': 'Eukaryota', 'Rank': 'superkingdom'}, {'TaxId': '33154', 'ScientificName': 'Opisthokonta', 'Rank': 'clade'}, {'TaxId': '33208', 'ScientificName': 'Metazoa', 'Rank': 'kingdom'}, {'TaxId': '6072', 'ScientificName': ...
#   Processing: Zaglossus bartoni
#   Processing: Zaglossus attenboroughi
#   Processing: Zaglossus bruijni
#   Processing: Tachyglossus aculeatus
#   Processing: Ornithorhynchus anatinus
# Fetched and processed 5 species.
#
# Taxonomic data saved to mammalia_taxonomy.json
# Macrauchenia sp. MW-2017: {'Phylum': 'Chordata', 'Class': 'Mammalia', 'Order': 'Litopterna', 'Family': 'Macraucheniidae', 'Genus': 'Macrauchenia', 'Synonyms': [], 'TaxId': '1970152'}
# Macrauchenia patachonica: {'Phylum': 'Chordata', 'Class': 'Mammalia', 'Order': 'Litopterna', 'Family': 'Macraucheniidae', 'Genus': 'Macrauchenia', 'Synonyms': [], 'TaxId': '1566623'}
# Macrauchenia sp. FW-2014: {'Phylum': 'Chordata', 'Class': 'Mammalia', 'Order': 'Litopterna', 'Family': 'Macraucheniidae', 'Genus': 'Macrauchenia', 'Synonyms': [], 'TaxId': '1563127'}
# Toxodon sp. FW-2014: {'Phylum': 'Chordata', 'Class': 'Mammalia', 'Order': 'Notoungulata', 'Family': 'Toxodontidae', 'Genus': 'Toxodon', 'Synonyms': [], 'TaxId': '1563122'}
# Cabassous tatouay: {'Phylum': 'Chordata', 'Class': 'Mammalia', 'Order': 'Cingulata', 'Family': 'Chlamyphoridae', 'Genus': 'Cabassous', 'Synonyms': ['Dasypus tatouay'], 'TaxId': '1756214'}

# %%
# If you want to load an existing taxonomy file, this is how you do it
species_data_file = './taxonomy_data/mammalia_taxonomy.json'
with open(species_data_file, 'r') as f:
    species_data = json.load(f)

# %% [markdown]
# ## <font color=#c994c7>Step 2: Query NCBI For a Protein Group/Family of Interest</font>

# %%
# Convert all the species we found in our NCBI taxonomy search to a list.
# The species names are the KEYS in the dictionary we created during the search.
species_list = list(species_data.keys())

# %%
query = f"(opsin[Title] OR rhodopsin[Title] OR OPN[Title] OR rh1[Title] OR rh2[Title] OR Rh1[Title] OR Rh2[Title]) NOT partial[Title] NOT voucher[All Fields] NOT kinase[All Fields] NOT kinase-like[All Fields] NOT similar[Title] NOT homolog[Title] NOT opsin-like[Title]"

# Remember, if you hover your mouse over any of MY functions then you should get a pop-up with more information on how to use them
ncbi_query_df, query_report_dir = ncbi_mine_seq_data(email=email, job_label='ncbi_mammalia_opsins', out='ncbi_mammalia_opsins', species_list=species_list[0:50], taxa_dictionary=species_data, query=query)
# Out:
# Creating Job Directory
#
# Saving Species Query List to Text
#
# Starting Queries to NCBI for DNA/Protein Sequences
#   0% (0 of 50) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--
#   2% (1 of 50) |                         | Elapsed Time: 0:00:01 ETA:   0:01:02
#   4% (2 of 50) |#                        | Elapsed Time: 0:00:02 ETA:   0:01:02
#   6% (3 of 50) |#                        | Elapsed Time: 0:00:03 ETA:   0:01:02
#   8% (4 of 50) |##                       | Elapsed Time: 0:00:07 ETA:   0:01:24
#  10% (5 of 50) |##                       | Elapsed Time: 0:00:10 ETA:   0:01:32
#  12% (6 of 50) |###                      | Elapsed Time: 0:00:18 ETA:   0:02:16
#  14% (7 of 50) |###                      | Elapsed Time: 0:00:20 ETA:   0:02:04
#  16% (8 of 50) |####                     | Elapsed Time: 0:00:21 ETA:   0:01:53
#  18% (9 of 50) |####                     | Elapsed Time: 0:00:23 ETA:   0:01:45
#  20% (10 of 50) |####                    | Elapsed Time: 0:00:24 ETA:   0:01:38
#  22% (11 of 50) |#####                   | Elapsed Time: 0:00:26 ETA:   0:01:32
#  24% (12 of 50) |#####                   | Elapsed Time: 0:00:27 ETA:   0:01:27
#  26% (13 of 50) |######                  | Elapsed Time: 0:00:28 ETA:   0:01:22
#  28% (14 of 50) |######                  | Elapsed Time: 0:00:30 ETA:   0:01:17
#  30% (15 of 50) |#######                 | Elapsed Time: 0:00:32 ETA:   0:01:15
#  32% (16 of 50) |#######                 | Elapsed Time: 0:00:33 ETA:   0:01:11
#  34% (17 of 50) |########                | Elapsed Time: 0:00:35 ETA:   0:01:08
#  36% (18 of 50) |########                | Elapsed Time: 0:00:36 ETA:   0:01:05
#  38% (19 of 50) |#########               | Elapsed Time: 0:00:38 ETA:   0:01:03
#  40% (20 of 50) |#########               | Elapsed Time: 0:00:40 ETA:   0:01:01
#  42% (21 of 50) |##########              | Elapsed Time: 0:00:42 ETA:   0:00:58
#  44% (22 of 50) |##########              | Elapsed Time: 0:00:43 ETA:   0:00:55
#  46% (23 of 50) |###########             | Elapsed Time: 0:00:46 ETA:   0:00:54
#  48% (24 of 50) |###########             | Elapsed Time: 0:00:48 ETA:   0:00:52
#  50% (25 of 50) |############            | Elapsed Time: 0:00:49 ETA:   0:00:49
#  52% (26 of 50) |############            | Elapsed Time: 0:00:50 ETA:   0:00:46
#  54% (27 of 50) |############            | Elapsed Time: 0:00:52 ETA:   0:00:44
#  56% (28 of 50) |#############           | Elapsed Time: 0:00:53 ETA:   0:00:42
#  58% (29 of 50) |#############           | Elapsed Time: 0:00:54 ETA:   0:00:39
#  60% (30 of 50) |##############          | Elapsed Time: 0:00:56 ETA:   0:00:37
#  62% (31 of 50) |##############          | Elapsed Time: 0:00:57 ETA:   0:00:35
#  64% (32 of 50) |###############         | Elapsed Time: 0:00:58 ETA:   0:00:33
#  66% (33 of 50) |###############         | Elapsed Time: 0:01:00 ETA:   0:00:31
#  68% (34 of 50) |################        | Elapsed Time: 0:01:01 ETA:   0:00:29
#  70% (35 of 50) |################        | Elapsed Time: 0:01:03 ETA:   0:00:27
#  72% (36 of 50) |#################       | Elapsed Time: 0:01:04 ETA:   0:00:25
#  74% (37 of 50) |#################       | Elapsed Time: 0:01:05 ETA:   0:00:23
#  76% (38 of 50) |##################      | Elapsed Time: 0:01:07 ETA:   0:00:21
#  78% (39 of 50) |##################      | Elapsed Time: 0:01:08 ETA:   0:00:19
#  80% (40 of 50) |###################     | Elapsed Time: 0:01:09 ETA:   0:00:17
#  82% (41 of 50) |###################     | Elapsed Time: 0:01:11 ETA:   0:00:15
#  84% (42 of 50) |####################    | Elapsed Time: 0:01:12 ETA:   0:00:13
#  86% (43 of 50) |####################    | Elapsed Time: 0:01:14 ETA:   0:00:12
#  88% (44 of 50) |#####################   | Elapsed Time: 0:01:16 ETA:   0:00:10
#  90% (45 of 50) |#####################   | Elapsed Time: 0:01:18 ETA:   0:00:08
#  92% (46 of 50) |######################  | Elapsed Time: 0:01:19 ETA:   0:00:06
#  94% (47 of 50) |######################  | Elapsed Time: 0:01:21 ETA:   0:00:05
#  96% (48 of 50) |####################### | Elapsed Time: 0:01:22 ETA:   0:00:03
#  98% (49 of 50) |####################### | Elapsed Time: 0:01:24 ETA:   0:00:01
# 100% (50 of 50) |########################| Elapsed Time: 0:01:24 Time:  0:01:24
# 100% (50 of 50) |########################| Elapsed Time: 0:01:24 Time:  0:01:24
# NCBI Queries Complete!
# Now Extracting and Formatting Results For DataFrame...
#
# DataFrame Formatted and Saved to CSV file for future use :)
#
# FASTA File Saved...
#
# Saving txt file with names of species that retrieved no results...

# %% [markdown]
# ## <font color=#c994c7>Step 3: Extract Candidate Genes From a Trasncriptome of Interest Using Queried Data</font>

# %%
import subprocess  # For running external programs like tblastx
import datetime    # For timestamping output filenames
import os          # For interacting with the filesystem

from blast_matching_functions import format_blast_db, run_blast_query

# %%
DB_folder = query_report_dir
QUERY_folder = "./transcriptomes/ostracod_seqData/aa"
results_folder = './blast_results'
job_name = 'opsin_trans_mining'

if not os.path.isdir(results_folder):
    os.makedirs(results_folder, exist_ok=True)

# blast parameters
evalue = "1e-5"
outfmt = "6"
blasttyp = 'blastp'

print("Checking DB folder:", DB_folder)
print("Checking QUERY folder:", QUERY_folder)

for db in os.listdir(DB_folder):
    if db.endswith('.fasta'):
        print("Found DB file:", db)
        db_path = os.path.join(DB_folder, db)
        # Format DB and get base path
        format_blast_db(db_path)
        db_base = os.path.splitext(db_path)[0]
    
        for query in os.listdir(QUERY_folder):
            if query.lower().endswith(('.fasta', '.fa', '.faa', '.pep')):
                print("Found QUERY file:", query)

                query_path = os.path.join(QUERY_folder, query)


                # Output file
                query_name = os.path.splitext(query)[0]
                time_stamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
                output_file = os.path.join(results_folder, f"{job_name}_{blasttyp}_{query_name}_{time_stamp}.txt")

                run_blast_query(blasttyp, query_path, db_base, output_file, evalue, outfmt)
# Out:
# Checking DB folder: mnm_data/mnm_on_ncbi_mammalia_opsins_2025-05-20_17-00-42
# Checking QUERY folder: ./transcriptomes/ostracod_seqData/aa
# Found DB file: mined_ncbi_mammalia_opsins_seqs.fasta
# Formatting BLAST DB for: mnm_data/mnm_on_ncbi_mammalia_opsins_2025-05-20_17-00-42\mined_ncbi_mammalia_opsins_seqs.fasta
# Database formatted successfully.
# Found QUERY file: Actinoseta_chelisparsa.fasta.transdecoder.pep
# Running blastp...
# blastp search completed successfully!
# Results saved in: ./blast_results\opsin_trans_mining_blastp_Actinoseta_chelisparsa.fasta.transdecoder_2025-05-20_17-12-45.txt
#
# === Preview of Results ===
#
# Found QUERY file: Actinoseta_jonesi.fasta.transdecoder.pep
# Running blastp...
# blastp search completed successfully!
# Results saved in: ./blast_results\opsin_trans_mining_blastp_Actinoseta_jonesi.fasta.transdecoder_2025-05-20_17-12-46.txt
#
# === Preview of Results ===
# TRINITY_DN105_c0_g1_i1.p1	XM_004483219.2	30.233	215	145	3	7	220	152	362	2.13e-31	109
# TRINITY_DN105_c0_g1_i1.p1	XM_004477246.3	27.049	244	160	5	3	244	117	344	1.40e-28	100
# TRINITY_DN105_c0_g1_i1.p1	XM_004452792.2	26.442	208	139	4	6	211	118	313	4.57e-18	71.2
# TRINITY_DN105_c0_g1_i1.p1	XM_058275368.1	24.118	170	113	4	42	206	321	479	7.80e-11	50.1
# TRINITY_DN105_c0_g1_i1.p1	XM_004463203.4	26.277	137	95	3	1	132	114	249	1.65e-06	36.6
# TRINITY_DN105_c0_g1_i10.p1	XM_004483219.2	33.333	165	95	3	5	163	207	362	9.03e-26	91.7
# TRINITY_DN105_c0_g1_i10.p1	XM_004477246.3	25.946	185	120	4	5	187	175	344	5.56e-21	77.8
# TRINITY_DN105_c0_g1_i10.p1	XM_004452792.2	26.490	151	100	2	6	154	172	313	6.63e-14	57.8
# TRINITY_DN105_c0_g1_i10.p1	XM_058275368.1	29.268	82	57	1	74	154	403	484	1.53e-08	42.0
# TRINITY_DN105_c0_g1_i12.p1	XM_004483219.2	30.233	215	145	3	7	220	152	362	2.13e-31	109
#
# Found QUERY file: Alternochelata_lizardensis_SRR6876202.fasta.transdecoder.pep
# Running blastp...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 37
#      34 time_stamp = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
#      35 output_file = os.path.join(results_folder, f"{job_name}_{blasttyp}_{query_name}_{time_stamp}.txt")
# ---> 37 run_blast_query(blasttyp, query_path, db_base, output_file, evalue, outfmt)
#
# File e:\safra\Documents\GitHub\mine_n_match\blast_matching_functions.py:20, in run_blast_query(blasttyp, QUERY_FILE, DB_FILE, OUTPUT_FILE, EVALUE, OUTFMT)
#      10 blast_cmd = [
#      11     blasttyp,             # BLAST tool to run
#      12     "-query", QUERY_FILE,  # Your transcriptome FASTA file
#    (...)
#      16     "-outfmt", OUTFMT      # Output format (e.g., tabular format)
#      17 ]
#      19 print(f"Running {blasttyp}...")
# ---> 20 result = subprocess.run(blast_cmd, capture_output=True, text=True)
#      22 if result.stderr:
#      23     print(f"Error running {blasttyp}:", result.stderr)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\subprocess.py:507, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     505 with Popen(*popenargs, **kwargs) as process:
#     506     try:
# --> 507         stdout, stderr = process.communicate(input, timeout=timeout)
#     508     except TimeoutExpired as exc:
#     509         process.kill()
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\subprocess.py:1134, in Popen.communicate(self, input, timeout)
#    1131     endtime = None
#    1133 try:
# -> 1134     stdout, stderr = self._communicate(input, endtime, timeout)
#    1135 except KeyboardInterrupt:
#    1136     # https://bugs.python.org/issue25942
#    1137     # See the detailed comment in .wait().
#    1138     if timeout is not None:
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\subprocess.py:1524, in Popen._communicate(self, input, endtime, orig_timeout)
#    1520 # Wait for the reader threads, or time out.  If we time out, the
#    1521 # threads remain reading and the fds left open in case the user
#    1522 # calls communicate again.
#    1523 if self.stdout is not None:
# -> 1524     self.stdout_thread.join(self._remaining_time(endtime))
#    1525     if self.stdout_thread.is_alive():
#    1526         raise TimeoutExpired(self.args, orig_timeout)
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\threading.py:1060, in Thread.join(self, timeout)
#    1057     raise RuntimeError("cannot join current thread")
#    1059 if timeout is None:
# -> 1060     self._wait_for_tstate_lock()
#    1061 else:
#    1062     # the behavior of a negative timeout isn't documented, but
#    1063     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1064     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File c:\Users\safra\anaconda3\envs\deepBreaks\lib\threading.py:1080, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1077     return
#    1079 try:
# -> 1080     if lock.acquire(block, timeout):
#    1081         lock.release()
#    1082         self._stop()
#
# KeyboardInterrupt:
